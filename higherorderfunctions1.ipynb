# %%
def name(vinoth,x,y,z):
  print(vinoth(x,y,z)
  )

# %%
def multi(x,y,z):
  for i in range(1,21):
    print(i,"*",x,"=",i*x)
  for i in range(1,21):
    print(i,"*",y,"=",i*y)
  for i in range(1,21):
    print(i,"*",z,"=",i*z)

# %%
def three(x,y,z):
  for in range(1,11):
    print(i,"*",x,"=",i*x)
  for j in range(1,11):
